# %%
import os
import getpass
# !pip install langchain_google_genai


os.environ['GOOGLE_API_KEY'] = getpass.getpass('Enter your API key')#AIzaSyDQuk0zWuc7rXSjfmnzzoZBVUk5ViMNBno
from langchain_google_genai import ChatGoogleGenerativeAI

# If there is no env variable set for API key, you can pass the API key
# to the parameter `google_api_key` of the `ChatGoogleGenerativeAI` function:
# `google_api_key="key"`.

llm = ChatGoogleGenerativeAI(
model="gemini-pro",
temperature=0.7,
top_p=0.85,
google_api_key=os.environ.get('GOOGLE_API_KEY'),
)
#2. Models
#LangChain integrates with various language models, allowing you to interact with them programmatically.


from langchain.schema import HumanMessage

# Generate a response
text = "Write a short story about mahabharatha"
messages = [HumanMessage(content=text)] # Wrap the text in a HumanMessage
print(llm(messages)) # Pass the list of messages to the llm

#3. Prompt Template
from langchain.prompts import PromptTemplate

template = "Translate the following text to Tamil and french: {text}"
prompt = PromptTemplate(input_variables=["text"], template=template)

# Usage
prompt_text = prompt.format(text="I am Tejashvar the great")
print(prompt_text) # Output: Translate the following text to tamil and french: I am Tejashvar the great
# Generate a response
messages = [HumanMessage(content=prompt_text)] # Wrap the prompt_text in a HumanMessage
response = llm(messages) # Pass the list of messages to the llm
print(response)
# Out:
# ...
# Enter your API key··········
# ...
