# %%
#Temperature comparison
# Install necessary packages
# !pip install google-generativeai python-dotenv

# Import required libraries
import google.generativeai as genai

# Define the API key directly in the variable
google_api_key = "AIzaSyDQuk0zWuc7rXSjfmnzzoZBVUk5ViMNBno"

# Configure the Google Generative AI library with API key
genai.configure(api_key=google_api_key)

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 750,
    "response_mime_type": "text/plain",
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-pro",
    generation_config=generation_config
)

# Start a chat session
chat_session = model.start_chat(history=[])
user_input=input("Enter your prompt")
# Send a message to the chat model
response = chat_session.send_message(user_input)

# Print the response text
print(response.text)
# Out:
# ...
# Enter your promptgenerative ai
# Generative AI refers to a category of artificial intelligence algorithms that can create new content, ranging from text and code to images, audio, video, and even 3D models.  Instead of simply analyzing or classifying existing data, generative AI learns the underlying patterns and structure of the input data and then uses this knowledge to generate similar but novel outputs.
#
# Here's a breakdown of key aspects of generative AI:
#
# **How it works:**
#
# * **Training Data:** Generative AI models are trained on massive datasets of text, images, audio, etc.  This data allows the model to learn the statistical relationships and patterns within the data.
# * **Generative Models:**  Several different types of models are used for generative AI, including:
# ...

# %%
#temperature comparison
# Install necessary packages


# Import required libraries
import google.generativeai as genai

# Define the API key directly in the variable
google_api_key = "AIzaSyDQuk0zWuc7rXSjfmnzzoZBVUk5ViMNBno"  # Replace with actual API key

# Configure the Google Generative AI library with API key
genai.configure(api_key=google_api_key)

# Create the model configuration
generation_config = {
    "temperature": 0.1,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 750,
    "response_mime_type": "text/plain",
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-pro",
    generation_config=generation_config
)

# Start a chat session
chat_session = model.start_chat(history=[])
user_input=input("Enter your prompt")
# Send a message to the chat model
response = chat_session.send_message(user_input)

# Print the response text
print(response.text)
# Out:
# Enter your promptgenerative ai
# Generative AI refers to a category of artificial intelligence algorithms that can create new content, ranging from text and code to images, music, and even videos.  Instead of simply analyzing or classifying existing data, generative AI learns the underlying patterns and structures of the input data and then uses this knowledge to generate similar, but novel, outputs.
#
# Here's a breakdown of key aspects:
#
# **How it works:**
#
# * **Training Data:** Generative AI models are trained on massive datasets of text, images, audio, or other data.
# * **Learning Patterns:**  The model learns the statistical patterns, structures, and features within the data.
# * **Generating New Content:** Based on the learned patterns, the model can generate new content that resembles the training data but isn't a direct copy.  It can be prompted to create specific types of content based on user input.
#
# **Key Techniques:**
#
# ...

# %%
#number of tokens comparison


# Import required libraries
import google.generativeai as genai

# Define the API key directly in the variable
google_api_key = "AIzaSyDQuk0zWuc7rXSjfmnzzoZBVUk5ViMNBno"  # Replace with actual API key

# Configure the Google Generative AI library with API key
genai.configure(api_key=google_api_key)

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 100,
    "response_mime_type": "text/plain",
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-pro",
    generation_config=generation_config
)

# Start a chat session
chat_session = model.start_chat(history=[])
user_input=input("Enter your prompt")
# Send a message to the chat model
response = chat_session.send_message(user_input)

# Print the response text
print(response.text)
# Out:
# Enter your promptgenerative ai
# Generative AI refers to a category of artificial intelligence algorithms that can create new content, ranging from text, images, audio, and video to code, 3D models, and other data formats.  It learns from input training data and then generates new, similar content that reflects the patterns and structure it learned.
#
# Here's a breakdown of key aspects:
#
# **How it works:**
#
# * **Training Data:** Generative AI models are trained on massive datasets.  The model learns the

# %%
# no of tokens


# Import required libraries
import google.generativeai as genai

# Define the API key directly in the variable
google_api_key = "AIzaSyDQuk0zWuc7rXSjfmnzzoZBVUk5ViMNBno"  # Replace with  actual API key

# Configure the Google Generative AI library with API key
genai.configure(api_key=google_api_key)

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 500,
    "response_mime_type": "text/plain",
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-pro",
    generation_config=generation_config
)

# Start a chat session
chat_session = model.start_chat(history=[])
user_input=input("Enter your prompt")
# Send a message to the chat model
response = chat_session.send_message(user_input)

# Print the response text
print(response.text)
# Out:
# Enter your promptgenerative ai
# Generative AI refers to a category of artificial intelligence algorithms that can generate new content, ranging from text and code to images, audio, video, and even 3D models. Unlike other AI systems that are designed for tasks like classification or prediction, generative AI focuses on creating something new.
#
# Here's a breakdown of key aspects:
#
# **How it works:**
#
# * **Learning Underlying Patterns:** Generative AI models learn the underlying patterns and structure of the input data they are trained on.  This allows them to generate outputs that resemble the training data in style and content.
# * **Probabilistic Generation:**  These models don't simply copy the training data. They use probabilistic methods to generate variations and novel combinations, creating something "new."
# * **Different Architectures:**  Various architectures are used for generative AI, including:
# ...

# %%
#top-p comparison
# no of tokens
# Install necessary packages
#!pip install google-generativeai python-dotenv

# Import required libraries
import google.generativeai as genai

# Define the API key directly in the variable
google_api_key = "AIzaSyDQuk0zWuc7rXSjfmnzzoZBVUk5ViMNBno"  # Replace with actual API key

# Configure the Google Generative AI library with  API key
genai.configure(api_key=google_api_key)

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.5,
    "top_k": 40,
    "max_output_tokens": 500,
    "response_mime_type": "text/plain",
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-pro",
    generation_config=generation_config
)

# Start a chat session
chat_session = model.start_chat(history=[])
user_input=input("Enter your prompt")
# Send a message to the chat model
response = chat_session.send_message(user_input)

# Print the response text
print(response.text)
# Out:
# Enter your promptgenerative ai
# Generative AI refers to a category of artificial intelligence algorithms that can create new content, ranging from text and code to images, music, and even 3D models.  Instead of simply analyzing or classifying existing data, generative AI learns the underlying patterns and structure of the input data and then uses this knowledge to generate similar but novel outputs.
#
# Here's a breakdown of key aspects of generative AI:
#
# **How it works:**
#
# * **Learning from data:** Generative AI models are typically trained on massive datasets.  They learn the statistical properties and relationships within the data.
# * **Generating new content:**  After training, the model can generate new data points that resemble the training data in terms of style, structure, and content.  The generated output is not simply copied from the training data but is a novel creation based on the learned patterns.
# ...

# %%
#top-k comparison
# Install necessary packages
#!pip install google-generativeai python-dotenv

# Import required libraries
import google.generativeai as genai

# Define the API key directly in the variable
google_api_key = "AIzaSyDQuk0zWuc7rXSjfmnzzoZBVUk5ViMNBno"  # Replace with actual API key

# Configure the Google Generative AI library with  API key
genai.configure(api_key=google_api_key)

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.5,
    "top_k": 20,
    "max_output_tokens": 500,
    "response_mime_type": "text/plain",
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-pro",
    generation_config=generation_config
)

# Start a chat session
chat_session = model.start_chat(history=[])
user_input=input("Enter your prompt")
# Send a message to the chat model
response = chat_session.send_message(user_input)

# Print the response text
print(response.text)
# Out:
# Enter your promptgenerative ai
# Generative AI refers to a category of artificial intelligence algorithms that can create new content, ranging from text and code to images, audio, video, and even 3D models.  Instead of simply analyzing or classifying existing data, generative AI learns the underlying patterns and structure of the input data and then uses this knowledge to generate similar but novel outputs.
#
# Here's a breakdown of key aspects of generative AI:
#
# **How it works:**
#
# * **Training Data:** Generative AI models are trained on massive datasets of text, images, audio, or other data.  This training allows the model to learn the statistical patterns and relationships within the data.
# * **Generative Process:**  After training, the model can generate new content by sampling from the learned distribution.  It doesn't simply copy the training data but creates variations based on the patterns it has learned.  This is often achieved through probabilistic methods.
# ...

# %%
# Install necessary packages
#!pip install google-generativeai python-dotenv

# Import required libraries
import google.generativeai as genai

# Define the API key directly in the variable
google_api_key = "AIzaSyDQuk0zWuc7rXSjfmnzzoZBVUk5ViMNBno"  # Replace with actual API key

# Configure the Google Generative AI library with  API key
genai.configure(api_key=google_api_key)

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.5,
    "top_k": 40,
    "max_output_tokens": 500,
    "response_mime_type": "text/plain",
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-pro",
    generation_config=generation_config
)

# Start a chat session
chat_session = model.start_chat(history=[])
user_input=input("Enter your prompt")
# Send a message to the chat model
response = chat_session.send_message(user_input)

# Print the response text
print(response.text)
# Out:
# Enter your promptgenerative ai
# Generative AI refers to a category of artificial intelligence algorithms designed to create new content, ranging from text and code to images, audio, video, 3D models, and even simulated environments.  Instead of simply analyzing or classifying existing data, generative AI learns the underlying patterns and structure of the input data and then uses this knowledge to generate similar, yet novel, outputs.
#
# Key aspects of Generative AI:
#
# * **Models:**  Several models power generative AI, including:
#     * **Generative Adversarial Networks (GANs):**  Two neural networks, a generator and a discriminator, compete against each other. The generator creates content, and the discriminator tries to distinguish it from real data. This adversarial process pushes the generator to produce increasingly realistic outputs.
# ...

# %%
#frequency penalty comparison
# Install necessary packages
#!pip install google-generativeai python-dotenv

# Import required libraries
import google.generativeai as genai

# Define the API key directly in the variable
google_api_key = "AIzaSyDQuk0zWuc7rXSjfmnzzoZBVUk5ViMNBno"  # Replace with  actual API key

# Configure the Google Generative AI library with  API key
genai.configure(api_key=google_api_key)

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.5,
    "top_k": 40,
    "max_output_tokens": 500,
    "response_mime_type": "text/plain",
    "frequency_penalty": 0.5,
    "presence_penalty": 0,
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-pro",
    generation_config=generation_config
)

# Start a chat session
chat_session = model.start_chat(history=[])
user_input=input("Enter your prompt")
# Send a message to the chat model
response = chat_session.send_message(user_input)

# Print the response text
print(response.text)
# Out:
# Enter your promptgenerative ai
# Generative AI refers to a category of artificial intelligence algorithms that can create new content, ranging from text and images to audio, code, 3D models, videos, and other data.  Instead of simply analyzing or classifying existing data, generative AI learns the underlying patterns and structure of the input data and then uses this knowledge to generate similar but novel outputs.
#
# Here's a breakdown of key aspects of generative AI:
#
# **How it works:**
#
# * **Learning from data:** Generative AI models are typically trained on massive datasets.  They learn the statistical properties and relationships within the data.
# * **Generating new content:** After training, these models can generate new data points that resemble the training data in terms of style, content, and structure, but are not mere copies.  They create something new based on the learned patterns.
# ...

# %%
#frequency penalty comparison
# Install necessary packages
#!pip install google-generativeai python-dotenv

# Import required libraries
import google.generativeai as genai

# Define the API key directly in the variable
google_api_key = "AIzaSyDQuk0zWuc7rXSjfmnzzoZBVUk5ViMNBno"  # Replace with actual API key

# Configure the Google Generative AI library with  API key
genai.configure(api_key=google_api_key)

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.5,
    "top_k": 40,
    "max_output_tokens": 500,
    "response_mime_type": "text/plain",
    "frequency_penalty": 1,
    "presence_penalty": 0,
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-pro",
    generation_config=generation_config
)

# Start a chat session
chat_session = model.start_chat(history=[])
user_input=input("Enter your prompt")
# Send a message to the chat model
response = chat_session.send_message(user_input)

# Print the response text
print(response.text)
# Out:
# Enter your promptgenerative ai
# Generative AI refers to a category of artificial intelligence algorithms designed to create new content, ranging from text and code to images, audio, video, and even 3D models.  Instead of simply analyzing existing data, generative AI learns the underlying patterns and structure of the input data and then uses this knowledge to generate similar but novel outputs.
#
# Here's a breakdown of key aspects:
#
# **How it works:**
#
# * **Training Data:** Generative AI models are trained on massive datasets of text, images, audio, etc.  This data is used to learn the statistical properties and relationships within the data.
# * **Model Architectures:**  Several architectures are used, including:
# ...

# %%
#presence penalty comparison
# Install necessary packages
#!pip install google-generativeai python-dotenv

# Import required libraries
import google.generativeai as genai

# Define the API key directly in the variable
google_api_key = "AIzaSyDQuk0zWuc7rXSjfmnzzoZBVUk5ViMNBno"  # Replace with  actual API key

# Configure the Google Generative AI library with  API key
genai.configure(api_key=google_api_key)

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.5,
    "top_k": 40,
    "max_output_tokens": 500,
    "response_mime_type": "text/plain",
    "frequency_penalty": 0.5,
    "presence_penalty": 0,
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-pro",
    generation_config=generation_config
)

# Start a chat session
chat_session = model.start_chat(history=[])
user_input=input("Enter your prompt")
# Send a message to the chat model
response = chat_session.send_message(user_input)

# Print the response text
print(response.text)
# Out:
# Enter your promptgenerative ai
# Generative AI refers to a category of artificial intelligence algorithms that can create new content, ranging from text and code to images, audio, video, and even 3D models.  Instead of simply analyzing or classifying existing data, generative AI learns the underlying patterns and structure of the input data and then uses this knowledge to generate similar but novel outputs.
#
# Here's a breakdown of key aspects of generative AI:
#
# **How it works:**
#
# * **Learning from data:** Generative AI models are typically trained on massive datasets.  They learn the statistical properties and relationships within the data.
# * **Generating new content:** After training, these models can generate new data points that resemble the training data in terms of style, content, and structure.  The generated content is not simply copied from the training data but is novel and often creative.
# ...

# %%
#presence penalty comparison
# Install necessary packages
#!pip install google-generativeai python-dotenv

# Import required libraries
import google.generativeai as genai

# Define the API key directly in the variable
google_api_key = "AIzaSyDQuk0zWuc7rXSjfmnzzoZBVUk5ViMNBno"  # Replace with  actual API key

# Configure the Google Generative AI library with  API key
genai.configure(api_key=google_api_key)

# Create the model configuration
generation_config = {
    "temperature": 1,
    "top_p": 0.5,
    "top_k": 40,
    "max_output_tokens": 500,
    "response_mime_type": "text/plain",
    "frequency_penalty": 0.5,
    "presence_penalty": 1,
}

# Initialize the model
model = genai.GenerativeModel(
    model_name="gemini-1.5-pro",
    generation_config=generation_config
)

# Start a chat session
chat_session = model.start_chat(history=[])
user_input=input("Enter your prompt")
# Send a message to the chat model
response = chat_session.send_message(user_input)

# Print the response text
print(response.text)
# Out:
# Enter your promptgenerative ai
# Generative AI refers to a category of artificial intelligence algorithms that can create new content, ranging from text and images to audio, code, 3D models, simulations, and even videos.  Instead of simply analyzing or classifying existing data, generative AI learns the underlying patterns and structure of the input data and then uses this knowledge to generate similar but novel outputs.
#
# Here's a breakdown of key aspects:
#
# **How it works:**
#
# * **Training Data:** Generative AI models are trained on massive datasets of text, images, audio, or other data.  This training allows the model to learn the statistical properties and relationships within the data.
# ...
